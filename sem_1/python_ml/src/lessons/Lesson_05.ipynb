# %% [markdown]
# <center>
#
# # Курс "Основы Python для анализа данных"
#
# ## Артамонов Игорь Михайлович
# ## Факультет "Прикладная математика" МАИ
#
# ### Практическое № 5.  Ввод и вывод. Работа с реляционными базами данных.
#
# </center>

# %% [markdown]
# ## Общение / вопросы по курсу
#
# Платформа для групповой работы Atlassian Confluence факультета "Прикладная математика"
#
# https://mai.moscow/display/PYTML

# %% [markdown]
# * <b>Занятие 5. Ввод и вывод. Реляционные базы данных.</b>
#        *

# %% [markdown]
# ## virtualenv + Jupyter notebook

# %% [markdown]
# ```
# <Ctrl> + <Alt> + T - новое окно терминала
# ```

# %% [markdown]
# ```
# $ conda -V
#
# $ conda update conda
#
# $ conda search "^python$"
#
# $ conda create -n yourenvname python=x.x anaconda
#
# $ source activate yourenvname
#
# $ jupyter notebook
#
# $ conda install -n yourenvname [package]
# ```

# %% [markdown]
# # Общее

# %% [markdown]
# * В Python присутсвует ввод-вывод, аналогичный другим императивным языкам программирования
# * Однако, в подавляющем __большинстве случаев__, используются __специфические__ для конкретной области средства ввода-вывода
# * При анализе задачи __ввода__, целесообразно ответить на следующие вопросы:
#     - что нам надо ввести
#     - где мы это будем использовать
#     - в каком формате хранятся данные во входном файле
#     - в какой формат они загружаются в программе
#     - в каком формате нам их удобно будет использовать
# * При анализе задачи __вывода__ вопросы похожи, но последовательность близка к обратной:
#     - в каком формате мы имеем данные после обработки
#     - какова цель сохранения
#     - какие средства сохранения в нужный нам тип есть
#     - из какого формата сохраняет данное средство ввода-вывода
# * Работа с табличными данными - одна из сильных сторон Python, в том числе - благодаря вводу-выводу

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sc
# %matplotlib inline

# %%
import os
import os.path

# %% [markdown]
# ### Загрузка файлов из внешних источников

# %%
# "!" - для выполнения внешней команды из юпитера
# !wget -O kinglear.txt 'http://shakespeare.mit.edu/lear/full.html'
# Out:
# "wget" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %% [markdown]
# ### Ввод из файлов

# %%
kinglear = 'kinglear.txt'
file1 = open(kinglear,"r")  
# r - для чтения построчно
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-28fba3a563d3> in <module>
#       1 kinglear = 'kinglear.txt'
# ----> 2 file1 = open(kinglear,"r")
#       3 # r - для чтения построчно
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kinglear.txt'

# %%
# !pwd
# Out:
# "pwd" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %%
# %pwd  #  % - обертка юпитера для обычных команд
# Out:
# 'C:\\Users\\Алескандр\\Downloads'

# %%
# %ls -la
# Out:
#  ’®¬ ў гбва®©бвўҐ C ­Ґ Ё¬ҐҐв ¬ҐвЄЁ.
#  ‘ҐаЁ©­л© ­®¬Ґа в®¬ : 2269-C3D5
#
#  ‘®¤Ґа¦Ё¬®Ґ Ї ЇЄЁ C:\Users\Ђ«ҐбЄ ­¤а\Downloads
# ” ©« ­Ґ ­ ©¤Ґ­

# %%
path = ''
name = 'kinglear.txt'
finename = os.path.join(path, name)   # связывает два пути
file = open(finename,"r")

# %%
file.name
# Out:
# 'kinglear.txt'

# %%
file.mode  #  режим в котором файл открыт
# Out:
# 'r'

# %%
content=file.read()  # загружаем ВЕСЬ файл
print(content)
# Out:
# test
# test2
# test3

# %%
len(content)
# Out:
# 16

# %%
content[:110]  # обращение по символам
# Out:
# 'test\ntest2\ntest3'

# %%
file.close()

# %% [markdown]
# ### Использование with

# %%
with open(finename,"r") as file:
    l=file.read(10)
    print('1:', l)
    l=file.read(20)
    print('2:', l)
    l=file.read(30)
    print('3:', l)
# Out:
# 1: test
# test2
# 2:
# test3
# 3:

# %% [markdown]
# ## <font color=red>ЗАДАНИЕ</font>

# %% [markdown]
# Введите первые 5 строк файла, распечатайте и выведите в файл с именем 'myfile1.txt'

# %%
## Ваш код ниже
with open(finename,"r") as file:
    newFile = open("myfile.txt", 'w+')
    for line in file:
        print(line)
        newFile.write(line)
# Out:
# test1
#
# test2
#
# test3
#
# test4
#
# test5

# %%
# или
with open(finename,"r") as file:
    lines = list()
    for i in range(5):

# %% [markdown]
# ### Сериализованный ввод/вывод. Pickle

# %% [markdown]
# * Протокол pickle зависит от Python
# * нет гарантий совместимости между разными версиями Python
# * нет гарантий совместимости с другими языками программирования
# * не все структуры данных Python можгут быть сериализованы pickle

# %%
# пикл считывается из файла очень быстро (несколько порядков)

# %%
import pickle

# %%
pickle_name = 'city.pickle'

# %%
data = {}
data['Москва'] = [16, 27, 15, 22],
data['Санкт-Петербург'] = [11, 19, 29, 5],
data['Нососибирск'] = [2, 23, 3, 15],
data['Томск'] = [8, 9, 10, 7],
data['Верхний Волочок'] = [96, 5, 6, 74]
data
# Out:
# {'Москва': ([16, 27, 15, 22],),
#  'Санкт-Петербург': ([11, 19, 29, 5],),
#  'Нососибирск': ([2, 23, 3, 15],),
#  'Томск': ([8, 9, 10, 7],),
#  'Верхний Волочок': [96, 5, 6, 74]}

# %%
with open(pickle_name, 'wb') as file:
     pickle.dump(data, file)   # сохраняет пикл в файл

# %%
with open(pickle_name, 'rb') as file:
     new_data = pickle.load(file)  # загружает пикл из файла

# %%
print(new_data)
# Out:
# {'Москва': ([16, 27, 15, 22],), 'Санкт-Петербург': ([11, 19, 29, 5],), 'Нососибирск': ([2, 23, 3, 15],), 'Томск': ([8, 9, 10, 7],), 'Верхний Волочок': [96, 5, 6, 74]}

# %%
# Посмотрим внутрь файла
file = open(pickle_name,"rb")  # r - файл трактуется как текст с кодировкой, rb -бинарный файл 
content=file.read()
print(content)
# Out:
# b'\x80\x03}q\x00(X\x0c\x00\x00\x00\xd0\x9c\xd0\xbe\xd1\x81\xd0\xba\xd0\xb2\xd0\xb0q\x01]q\x02(K\x10K\x1bK\x0fK\x16e\x85q\x03X\x1d\x00\x00\x00\xd0\xa1\xd0\xb0\xd0\xbd\xd0\xba\xd1\x82-\xd0\x9f\xd0\xb5\xd1\x82\xd0\xb5\xd1\x80\xd0\xb1\xd1\x83\xd1\x80\xd0\xb3q\x04]q\x05(K\x0bK\x13K\x1dK\x05e\x85q\x06X\x16\x00\x00\x00\xd0\x9d\xd0\xbe\xd1\x81\xd0\xbe\xd1\x81\xd0\xb8\xd0\xb1\xd0\xb8\xd1\x80\xd1\x81\xd0\xbaq\x07]q\x08(K\x02K\x17K\x03K\x0fe\x85q\tX\n\x00\x00\x00\xd0\xa2\xd0\xbe\xd0\xbc\xd1\x81\xd0\xbaq\n]q\x0b(K\x08K\tK\nK\x07e\x85q\x0cX\x1d\x00\x00\x00\xd0\x92\xd0\xb5\xd1\x80\xd1\x85\xd0\xbd\xd0\xb8\xd0\xb9 \xd0\x92\xd0\xbe\xd0\xbb\xd0\xbe\xd1\x87\xd0\xbe\xd0\xbaq\r]q\x0e(K`K\x05K\x06KJeu.'

# %% [markdown]
# ### В чём проблема?

# %%
bytes_read = open(pickle_name, "rb").read()
print(bytes_read )
# Out:
# b'\x80\x03}q\x00(X\x0c\x00\x00\x00\xd0\x9c\xd0\xbe\xd1\x81\xd0\xba\xd0\xb2\xd0\xb0q\x01]q\x02(K\x10K\x1bK\x0fK\x16e\x85q\x03X\x1d\x00\x00\x00\xd0\xa1\xd0\xb0\xd0\xbd\xd0\xba\xd1\x82-\xd0\x9f\xd0\xb5\xd1\x82\xd0\xb5\xd1\x80\xd0\xb1\xd1\x83\xd1\x80\xd0\xb3q\x04]q\x05(K\x0bK\x13K\x1dK\x05e\x85q\x06X\x16\x00\x00\x00\xd0\x9d\xd0\xbe\xd1\x81\xd0\xbe\xd1\x81\xd0\xb8\xd0\xb1\xd0\xb8\xd1\x80\xd1\x81\xd0\xbaq\x07]q\x08(K\x02K\x17K\x03K\x0fe\x85q\tX\n\x00\x00\x00\xd0\xa2\xd0\xbe\xd0\xbc\xd1\x81\xd0\xbaq\n]q\x0b(K\x08K\tK\nK\x07e\x85q\x0cX\x1d\x00\x00\x00\xd0\x92\xd0\xb5\xd1\x80\xd1\x85\xd0\xbd\xd0\xb8\xd0\xb9 \xd0\x92\xd0\xbe\xd0\xbb\xd0\xbe\xd1\x87\xd0\xbe\xd0\xbaq\r]q\x0e(K`K\x05K\x06KJeu.'

# %%
# Заодно создадим свой генератор
# считываем побайтово
def bytes_from_file(filename, chunksize=8192):
    with open(filename, "rb") as f:
        while True:
            chunk = f.read(chunksize)  # считываем блок (chunksize размера) из файла. Не загружаем сразу весь файл
            if chunk:  # если блок считался -> получили объект
                for b in chunk:  # пробегаемся по всем байтам в кусочке
                    yield b   # yiels - возвращает генератор (почти аналог return), именно один элемент
            else:  # получим None объект
                break

byte_no = 0
num_of_bytes = 16
# поулчим перечень первых 17 байт
for b in bytes_from_file(pickle_name, chunksize=32):
    print(f"#{byte_no:03d} - {b:02x}")
    byte_no += 1
    if byte_no > num_of_bytes:
        break
# Out:
# #000 - 80
# #001 - 03
# #002 - 7d
# #003 - 71
# #004 - 00
# #005 - 28
# #006 - 58
# #007 - 0c
# #008 - 00
# #009 - 00
# #010 - 00
# #011 - d0
# #012 - 9c
# #013 - d0
# #014 - be
# #015 - d1
# #016 - 81

# %% [markdown]
# ## <font color=red>ЗАДАНИЕ</font>

# %% [markdown]
# Создайте случайный массив numpy размером $10 x 10$, запишите его в виде pickle и заново считайте в другую переменную. Выведите среднее суммы квадратов разницы между массивом и им же, но транспонированным.

# %%
# Ваш код
ar = np.random.randn(10,10)
with open("pickle_name", 'wb') as file:
    pickle.dump(ar, file)
with open("pickle_name", 'rb') as file:
    ar1 = pickle.load(file) 
dif = ar1 - ar1.T
dif = dif ** 2
sum(sum(dif))
# или np.mean(dif), np.avarage(dif)
# Out:
# 150.68825193524071

# %% [markdown]
# ### Загрузка и открытие файлов из Интернет (URL)

# %%
import urllib
import urllib.request

# %%
with urllib.request.urlopen('http://lib.ru/LITRA/PUSHKIN/p4.txt') as url:
    i = 0
    if i < 5:  # файл открыт как бинарный (см вывод) но интерпретируем его как чтение по строкам
        print(url.readline())  # считываем по блокам
# Out:
# b'<html><head><title>\xe1\xcc\xc5\xcb\xd3\xc1\xce\xc4\xd2 \xf3\xc5\xd2\xc7\xc5\xc5\xd7\xc9\xde \xf0\xd5\xdb\xcb\xc9\xce. \xe4\xd2\xc1\xcd\xc1\xd4\xc9\xde\xc5\xd3\xcb\xc9\xc5 \xd0\xd2\xcf\xc9\xda\xd7\xc5\xc4\xc5\xce\xc9\xd1</title></head><body><pre><div align=right><form action=/LITRA/PUSHKIN/p4.txt><select name=format><OPTION VALUE="_Contents">\xf3\xcf\xc4\xc5\xd2\xd6\xc1\xce\xc9\xc5<OPTION VALUE="_with-big-pictures.html">Fine HTML<OPTION VALUE="_with-big-pictures.html">Printed version<OPTION VALUE="_Ascii.txt">txt(Word,\xeb\xf0\xeb)<OPTION VALUE="">Lib.ru html</select><input type=submit value=go></form></div><pre>\n'

# %%
from html.parser import HTMLParser

# %%
with urllib.request.urlopen('http://www.gutenberg.org/files/1532/1532-0.txt') as url:
    i = 0
    for line in url:  # вывод посрочно (не бинарно), но каждая строка (как байтовая последовательность)
        print(line.decode())  # декодируем, чтобы каждая строка была не как байтовая послед.
        if i > 4:
            break
        else:
            i +=1
# Out:
# Project Gutenberg’s King Lear, by William Shakespeare
#
#
#
# This eBook is for the use of anyone anywhere in the United States and
#
# most other parts of the world at no cost and with almost no restrictions
#
# whatsoever.  You may copy it, give it away or re-use it under the terms

# %% [markdown]
# ## <font color=red>ЗАДАНИЕ</font>

# %% [markdown]
# Преобразуйте файл в список строк с удалением форматирования так, что в каждом элементе
# списка - только строка. Если строка пустая, то она должна сохраняться пустой строкой.

# %%
# Ваш код

# %% [markdown]
# ## Использование даты и времени

# %% [markdown]
# * date — работа только с датой
# * time — работа со временем (независимо от дня) (Hour, minute, second, microsecond)
# * DateTime — Комбинация даты и времени (Month, day, year, hour, second, microsecond)
# * time delta — работа с временными разницами
# * tzinfo — работа с временными зонами

# %%
from datetime import date
from datetime import time
from datetime import datetime  # !!!!
from datetime import timedelta
from datetime import tzinfo

# %%
d = date.today()
d
# Out:
# datetime.date(2019, 10, 4)

# %%
d.day, d.month, d.year
# Out:
# (4, 10, 2019)

# %%
dt = datetime.today()
dt
# Out:
# datetime.datetime(2019, 10, 4, 19, 2, 10, 21082)

# %%
dt.day, dt.month, dt.year
# Out:
# (4, 10, 2019)

# %%
dt.hour, dt.minute, dt.second, dt.microsecond
# Out:
# (19, 2, 10, 21082)

# %%
tt = dt.timetuple()
for it in tt:
    print(it)
# Out:
# 2019
# 10
# 4
# 19
# 2
# 10
# 4
# 277
# -1

# %%
td = timedelta(days=700, hours=14, minutes=24)
td
# Out:
# datetime.timedelta(days=700, seconds=51840)

# %%
year = timedelta(days=365)
another_year = timedelta(weeks=40, days=84, hours=23, minutes=50, seconds=600)

# %%
year.total_seconds()
# Out:
# 31536000.0

# %%
year == another_year  # сравнивает количество секунд (переопределенная команда)
# Out:
# True

# %%
dt - year  # тип datetime минус timedelta = datetime
# Out:
# datetime.datetime(2018, 10, 4, 19, 2, 10, 21082)

# %% [markdown]
# #### Вывод даты и времени

# %%
dt.strftime("%A, %d-%B %Y %I:%M%p")   # A - день недели, d - числом
# Out:
# 'Friday, 04-October 2019 07:02PM'

# %% [markdown]
# ### Выведите количество (1) дней, (2) месяцев прошедшее с запуска первого искусственного спутника земли <br>(4 октября 1957)

# %%
## Ваш код
today = date.today()
lastday = date(1957, 10, 4)
delta = today - lastday
# чтобы получить месяцы: today = datetime(...), d timedelta нет месяцев т.к. разной длины
print(delta)
# Out:
# 22645 days, 0:00:00

# %% [markdown]
# ### JSON

# %% [markdown]
# * Популярный формат, пришедший из JavaScript
# * Поддерживает меньше форматов, чем pickle
# * Обеспечивает совместимость между языками программирования

# %%
import json

# %% [markdown]
# #### Соответствие типов данных в JSON и Python 3
# | JSON | PYTHON 3  |
# |--- |--- |
# | object | dict |
# | array | list |
# | string | string |
# | integer | integer |
# | real number | float |
# | true | True |
# | false | False |
# | null | None|

# %%
json.dumps(data)
# Out:
# '{"\\u041c\\u043e\\u0441\\u043a\\u0432\\u0430": [[16, 27, 15, 22]], "\\u0421\\u0430\\u043d\\u043a\\u0442-\\u041f\\u0435\\u0442\\u0435\\u0440\\u0431\\u0443\\u0440\\u0433": [[11, 19, 29, 5]], "\\u041d\\u043e\\u0441\\u043e\\u0441\\u0438\\u0431\\u0438\\u0440\\u0441\\u043a": [[2, 23, 3, 15]], "\\u0422\\u043e\\u043c\\u0441\\u043a": [[8, 9, 10, 7]], "\\u0412\\u0435\\u0440\\u0445\\u043d\\u0438\\u0439 \\u0412\\u043e\\u043b\\u043e\\u0447\\u043e\\u043a": [96, 5, 6, 74]}'

# %%
data
# Out:
# {'Москва': ([16, 27, 15, 22],),
#  'Санкт-Петербург': ([11, 19, 29, 5],),
#  'Нососибирск': ([2, 23, 3, 15],),
#  'Томск': ([8, 9, 10, 7],),
#  'Верхний Волочок': [96, 5, 6, 74]}

# %% [markdown]
# ```python
# {
#     "firstName": "Jane",
#     "lastName": "Doe",
#     "hobbies": ["running", "sky diving", "singing"],
#     "age": 35,
#     "children": [
#         {
#             "firstName": "Alice",
#             "age": 6
#         },
#         {
#             "firstName": "Bob",
#             "age": 8
#         }
#     ]
# }
# ```

# %%
with open("data.json", "w") as write_file:
    json.dump(data, write_file)

# %%
# !ls data.*
# Out:
# "ls" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %%
# %ls data.*
# Out:
#  ’®¬ ў гбва®©бвўҐ C ­Ґ Ё¬ҐҐв ¬ҐвЄЁ.
#  ‘ҐаЁ©­л© ­®¬Ґа в®¬ : 2269-C3D5
#
#  ‘®¤Ґа¦Ё¬®Ґ Ї ЇЄЁ C:\Users\Ђ«ҐбЄ ­¤а\Downloads
#
# 04.10.2019  19:20               412 data.json
#                1 д ©«®ў            412 Ў ©в
#                0 Ї Ї®Є  31я837я859я840 Ў ©в бў®Ў®¤­®

# %%
with open("data.json", "r") as read_file:
    decoded = json.load(read_file)
    
decoded
# Out:
# {'Москва': [[16, 27, 15, 22]],
#  'Санкт-Петербург': [[11, 19, 29, 5]],
#  'Нососибирск': [[2, 23, 3, 15]],
#  'Томск': [[8, 9, 10, 7]],
#  'Верхний Волочок': [96, 5, 6, 74]}

# %% [markdown]
# ### Модуль io

# %% [markdown]
# * работа с потоковым вводом-выводом
# * типы потоков вводв/вывода:
#     - текстовый
#     - двоичный
#     - небуфферизованый (raw)

# %%
import io

# %%
f = open("myfile.txt", "r", encoding="utf-8")

# %%
f = io.StringIO("some initial text data\nsome other data")

# %%
for c in f:
    print(c)
# Out:
# some initial text data
#
# some other data

# %%
f = io.BytesIO(b"some initial binary data: \x00\x01")
view = f.getbuffer()
view[2:4]

# %%
b = io.BytesIO(b"abcdef")
view = b.getbuffer()
view[2:4] = b"56"
b.getvalue()
# Out:
# b'ab56ef'

# %%
f = open(os.path.join('pics/', 'rembrandt.jpg'), "rb", buffering=0)

# %%
for i in range(10):
    print(f.read())
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x02\x00\x1c\x00\x1c\x00\x00\xff\xdb\x00C\x00\x03\x02\x02\x02\x02\x02\x03\x02\x02\x02\x03\x03\x03\x03\x04\x06\x04\x04\x04\x04\x04\x08\x06\x06\x05\x06\t\x08\n\n\t\x08\t\t\n\x0c\x0f\x0c\n\x0b\x0e\x0b\t\t\r\x11\r\x0e\x0f\x10\x10\x11\x10\n\x0c\x12\x13\x12\x10\x13\x0f\x10\x10\x10\xff\xdb\x00C\x01\x03\x03\x03\x04\x03\x04\x08\x04\x04\x08\x10\x0b\t\t\xff\xc4\x00J\x10\x00\x01\x03\x03\x02\x04\x04\x04\x04\x04\x06\x01\x04\x00\x00\x0f\x01\x02\x03\x04\x00\x05\x11\x12!\x06\x131A\x14"Qa\x072q\x81\x15#B\x913R\xa1\xb1\x08\x16$b\xc1\xd1\xe1Cr\xf0\xf1%\x174S\x82\x92\tD\x18&ETcs\xa2\xff\xc4\x00\x1b\x01\x00\x03\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x00\x05\x06\x07\xff\xc4\x002\x11\x00\x02\x02\x02\x02\x02\x02\x02\x02\x02\x02\x01\x04\x03\x00\x03\x00\x01\x02\x11\x03!\x121\x04A\x13"2Q\x05a\x14q#B\x15\x063R\x81Cb\x91\xa1$\xf0\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xfcV\xb6!?\x08\xb8\xdf\x95\xd5\x11\xe5\x1d\xab\r\xb3\xe8\xdaM\x15!\x01\x84\xe9bj\x94\xaf\xe4I\x19\xa3\xd8\x9d{\x07C|\xd9\x05\xb5\xc2R\xd6\x7f\x99;\xd3\t\xef\xa0\xa8\xde\x00\xca\x11\xe6\xc4u%\'\xa8OJ;\xed\x1d\xab\xa6\x83.|>\x8b\x85\xc1\xb7`G\x91!-!$\xe19H\xa5R\xa4t\xa0\x9b\xd1x\xb951\xb4\xc0<\x1e\xda\xd6\xd1\x00\xba\x84(\xab\xfb\xd2\xbdn\xc6R\xe5\xaa\x07\xbb4\xda]i\xdble0P\x00q\x058\xa0\xa4\xbd\x8e\xe3\xfa\n2xr;\x08\\8\xae\x89g\xf8\x85I\xc0&\x95\xa91\x97\x15\xd0\xbaS\xac\xcaqk\x90\xd2\x12\x91\xfaQ\xd6\xb9hf\xd3\xec\xb4\xc3\xe1\xa90\xf4\xb4\xec\x88\xf2\x0fB\xa4\x803]rLV\xa0\xd0\xdf\x87\xdd\xbd*\xd1*\xde\xd5\xcd\tc\x07\x1a\xd5\x8c\xedK%\x1b\xba\x0cyqj\xcc\xf3\xb1\x9bTa\t\xe6\x1cK\xe9p\x92\xe1\x1b(}j\x97\xec\x9a\xfd1km\xba]-AiO\xa9\x07}#4\xdf\xec\x1c\x97Hcn\x9f\x8b\xa3B\xe0\xc7$\xa0\x01\x95\x0cR\xb5\xad\x0c\xa7\xbd\x84\'\xc5^\xefK\rJ\xd2\xcaF\xca\'\xcb\\\xea1\x06\xe7-\x02J\x82\xf7\x8e\\w\x15\xac$\xe1+\x1b\x83\xf7\xae\xbfeR\xf4\xcb\x11\x98)R\xdfO\xe7\r\x91\x9e\xf4;\x0f@\x1c\xa5\xb8\xe1rB\x96;\xea=)\xee\x84\xe3\xbd\x84\xdb-\x97\x0b\xd3\xe65\xb62\xdeQ\xd8\x0cl\xaa-\xa8\xf6\x05\x07.\x8b\xa2\xc4n\xd3u2o\xaa.!\xa0S\xc8\x1b\x80~\x95\xcd\xf2U\x11\x14x\xca\xe4\x16Y\xb5JS\xd7\xf6\xe5\xa6:\t:\x18$\nWk\xeaU(\xbf\xb9\\\x8e&\x9b~`F\x94\x92\x98\xd1\xf6HOz^*,~o"\xa6-G\x88\x90\xb2\xf2\x1c\xe5\xa1\xb1\xa5 \x1e\xd5\xcd\xa4&\xdb\t\x8a\x96Bt\xb8J\x94\xa3\xfb\xd264PC\xca,e\xb8\xaci\t\x1fzN\xfb\x1f\xae\x82\xad\xf3\xe63\x05\xd5em\xa8\r\x8d$\xa2\x9b\x1e2tF\xd1\'\x91\xcfT\xb4\xa5iP\xf2\x83\xebFJ\xfa\x16-\xae\xc6E\xa8.\xd9\x90\xfbJdJ\xd6\n\xb7\xdc\x0cR&\xd4\xa9\xf4=\'\x1b\xf6Sq\x94.\xb1\x9b\x86_BR\x81\x82\x01\xebM\x15\xc5\xd8$\xf9*\x17s\xd7o@\x8a\xc3HZJ\x80\xd4zS\xea[b[\x8e\x91\xc7\xda\x90\xc1\xe6\x07|\xaa\xec\x93\xb5*h\xe6\x9a\xd9\xa2\xb1\xd8\xedO0\x89\xe2r#JI\x03 \x81\x90z\xe6\xa59\xc9k\xd1Xc\x8bV\x0b\xc4E\x98\x93\x8cx3\x03\x8awg\x1d\x07c\xf7\xae\x85\xb5l\x194\xe9\x16M0\xadp\xd8b\xddu\xcb\x8fc\x98\x94\x11\xe5\'\xbd\x18\xdc\x9d\xb4\t%\x15I\x84\xb3\xc2\xb0`\xbe\xdc\xfb\xa7\x11\xf3\xa3\xbe\x9dJJ\x16\x0e=\xab\x9eW%J;\n\xc5[r(}\xa9\xb7iF\x04k\xb0[\t\xd9\xa4\xad@y{\x7fJ\x16\xa2\xad\xa0\xd3\x93\xa4\xce\xbb`\x10\x19\r\xa6S\x0e\xc9\x04\x1eZU\x93\xf7\xa5\xf99\x0f\xf1\xd1\\\x86|\x13~.Sl\x17U\xd1);\xa6\x95;t\x87\xe3J\xd8\xb7\xc6K\x0f\t\x1a\x8b\x8e\xf4A\x1b\xe9\x15JUB\xee\xec\xb1\x13\x1bqX\xb8\x92\xb7\x95\xf2\xaco\x8a\x9c\x93\xff\x00\xa8\xc9\xaf\xfb\x17\xbc\x9btt\x0eS^!\xe5\xfc\xeaP\xf9Gj\x10m\xf64\x94R\xd03\xb0\xe3\xeaa\xd6\xe7\x04\x1c\x82R\x83\xd3z\xa2\x97\xf4I\xc5~\xc3\xa4\xden\xc1\x91mfs\xca\x8cz\x0c\xeeOzU\x08\xfeMl/$\xbf\x1b\x16\xc4\x8c\xf9\x96S\x1d\x87\x8b\xbdI\t\xde\x9d\xb5[\x11-\xe8\xec\x86_S\xab/\xb2\xb2\xa0w*\x1b\xd2\xa9!\xe9\xfb)J\xb58\x96\xd ...
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''

# %% [markdown]
# ### Почему такой выводом?

# %% [markdown]
# ### Ввод / вывод изображений

# %%
image_path = os.path.join('pics/', 'rembrandt2.png')
image = plt.imread(image_path, format=None)

# %%
type(image)
# Out:
# numpy.ndarray

# %%
# fig, ax = plt.subplots(figsize=(10, 10))
plt.imshow(image);  # вывод на экран

# %%
ax

# %% [markdown]
# ## <font color=red>ЗАДАНИЕ</font>

# %% [markdown]
# Нарисуйте квадрат черного цвета с толщиной линии $5$ и размерами $100 x 100$ по внешним границам с центром в геометрическом центре картины. Выведите получившееся изображение на экран. Код черного цвета - $0$

# %%
### Ваш код
data = np.array(image)
print(image.shape)
# Out:
# (1190, 1008, 4)

# %% [markdown]
# ### Работа с SQL-базой данных

# %%
import sqlite3
from sqlite3 import Error

# %%
conn = sqlite3.connect("my.db")

# %%
create_table_req = """CREATE TABLE person 
    (firstname varchar(15), 
     lastname varchar(20), 
     age number(3), 
     address varchar(30), 
     city varchar(20));"""

# %%
cursor = conn.cursor()

# %%
conn.execute(create_table_req)

# %%
insert_table_req = """INSERT INTO person
    (firstname,  lastname, age, address, city)
    VALUES ("{}", "{}", {}, "{}", "{}")
""" 
conn.execute(insert_table_req.format('Диего', 'Мендес', 25, 'Москва, Братиславская ул., 26, 178', 'Москва'))

# %%
insert_table_req.format('Диего', 'Мендес', 25, 173655, 'Москва, Братиславская ул., 26, 178', 'Москва')
# Out:
# 'INSERT INTO person\n    (firstname,  lastname, age, address, city)\n    VALUES ("Диего", "Мендес", 25, "173655", "Москва, Братиславская ул., 26, 178")\n'

# %%
cursor.execute("SELECT * FROM person")
rows = cursor.fetchall()
 
for row in rows:
    print(row)
# Out:
# ('Диего', 'Мендес', 25, 'Москва, Братиславская ул., 26, 178', 'Москва')

# %%
conn = sqlite3.connect(':memory:')

# %%
conn.execute('DROP TABLE person')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-359-bb1b27f135e5> in <module>
# ----> 1 conn.execute('DROP TABLE person')
#
# OperationalError: no such table: person

# %% [markdown]
# ## <font color=red>ЗАДАНИЕ</font>

# %% [markdown]
# Введите данные из файла по продажам авокадо в массив numpy . После этого вычислите средние значения всех столбцов средствами numpy и средствами SQL

# %% [markdown]
# Путь к файлу <i>datasets/Avocado Prices/avocado.csv</i><br><br>
#
# Либо его можно скачать по ссылке на kaggle.com:<br>
# https://www.kaggle.com/neuromusic/avocado-prices/

# %%
# Ваш код

# %% [markdown]
# ## Экзаменационные вопросы:

# %% [markdown]
# * Ввод и вывод из файла
# * Сериализованный ввод и вывод
# * JSON
# * Работа с SQL из Python
